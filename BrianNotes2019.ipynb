# %% [markdown]
# ### Code used to cleanup .git entries in vim
# ```bash
# find . -type d -name ".git" -exec echo "{}" \;
# find . -type d -name ".git" -exec rm -rf "{}" \;
# find . -type d -name ".git" -exec rm -rf "{}" \;
# ```

# %%
display < tumblr_inline_o78vu3va5J1raprkq_400.gif

# %%
ls -lah
# Out:
# total 108160
# drwx------+ 55 bring  IOWA\Domain Users   1.7K Sep 24 15:22 .
# drwxr-xr-x+ 79 bring  IOWA\Domain Users   2.5K Sep 24 15:22 ..
# -rw-r--r--@  1 bring  IOWA\Domain Users    14K Aug 20 09:29 .DS_Store
# drwxr-xr-x   6 bring  IOWA\Domain Users   192B Sep 24 14:29 .ipynb_checkpoints
# -rw-------   1 bring  IOWA\Domain Users     0B Jan 14  2019 .localized
# -rw-r--r--@  1 bring  IOWA\Domain Users   3.3K Aug 12 11:53 12082019_Joe.txt
# drwxr-xr-x   5 bring  IOWA\Domain Users   160B Feb  6  2019 2019BriGalFiles
# -rw-r--r--@  1 bring  IOWA\Domain Users   3.9K Sep 16 15:39 2019_09_16_JoeLetter.txt
# -rw-r--r--@  1 bring  IOWA\Domain Users   4.1K Jul 11 15:23 2019_11_07_JoeLetter.txt
# -rw-r--r--   1 bring  IOWA\Domain Users   3.6K Sep  5 15:49 2019_5_09_JoeLetter.txt
# -rw-r--r--   1 bring  IOWA\Domain Users   572B Sep 24 15:21 BrianNotes2019.Rmd
# -rw-r--r--   1 bring  IOWA\Domain Users   2.5M Sep 24 15:21 BrianNotes2019.ipynb
# ...

# %%
echo $SHELL
# Out:
# /bin/bash

# %%
display < ~/Documents/Screen\ Shot\ 2019-09-17\ at\ 11.54.51\ AM.png

# %% [markdown]
# #### Links:
# - https://www.datascienceatthecommandline.com/
# - https://www.datascienceworkshops.com/blog/ibash-notebook/
